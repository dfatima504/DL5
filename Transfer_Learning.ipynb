# %%
import torch
import torch.nn as nn
from torchvision import models, transforms
from PIL import Image
import json

# %%
# Image preprocessing (same for most pretrained models)
def preprocess_image(image_path):
    transform = transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize(
            mean=[0.485, 0.456, 0.406],
            std=[0.229, 0.224, 0.225]
        )
    ])

    image = Image.open(image_path).convert('RGB')
    image = transform(image).unsqueeze(0)  # add batch dimension
    return image

# %%
# Load models
vgg16 = models.vgg16(pretrained=True)
resnet50 = models.resnet50(pretrained=True)

# Set to evaluation mode
vgg16.eval()
resnet50.eval()
# Out:
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /root/.cache/torch/hub/checkpoints/vgg16-397923af.pth
# 100%|██████████| 528M/528M [00:04<00:00, 121MB/s]
# ...

# %%
# Load ImageNet class labels
import os

# Download the imagenet_class_index.json file if it doesn't exist
if not os.path.exists("imagenet_class_index.json"):
    # !wget https://s3.amazonaws.com/deep-learning-models/image-models/imagenet_class_index.json

with open("imagenet_class_index.json") as f:
    class_idx = json.load(f)

idx2label = {int(k): v[1] for k, v in class_idx.items()}

def predict(model, image):
    with torch.no_grad():
        outputs = model(image)
        probs = torch.nn.functional.softmax(outputs[0], dim=0)

        top5_prob, top5_catid = torch.topk(probs, 5)

        results = []
        for i in range(5):
            label = idx2label[top5_catid[i].item()]
            prob = top5_prob[i].item()
            results.append((label, prob))

        return results
# Out:
# --2026-04-02 15:01:05--  https://s3.amazonaws.com/deep-learning-models/image-models/imagenet_class_index.json
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 3.5.8.99, 16.15.207.251, 16.15.176.223, ...
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|3.5.8.99|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 35363 (35K) [application/octet-stream]
# Saving to: ‘imagenet_class_index.json’
#
# imagenet_class_inde 100%[===================>]  34.53K  --.-KB/s    in 0.02s
#
# 2026-04-02 15:01:05 (1.78 MB/s) - ‘imagenet_class_index.json’ saved [35363/35363]

# %%
image_path = "images.jpg"   # 👈 change this
image = preprocess_image(image_path)

# %%
alexnet = models.alexnet(pretrained=True)
resnet101 = models.resnet101(pretrained=True)
mobilenet = models.mobilenet_v2(pretrained=True)

alexnet.eval()
resnet101.eval()
mobilenet.eval()
# Out:
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=AlexNet_Weights.IMAGENET1K_V1`. You can also use `weights=AlexNet_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/alexnet-owt-7be5be79.pth" to /root/.cache/torch/hub/checkpoints/alexnet-owt-7be5be79.pth
# 100%|██████████| 233M/233M [00:05<00:00, 43.8MB/s]
# ...

# %%
print("\nAlexNet Predictions:")
for label, prob in predict(alexnet, image):
    print(f"{label}: {prob:.4f}")

print("\nResNet101 Predictions:")
for label, prob in predict(resnet101, image):
    print(f"{label}: {prob:.4f}")

print("\nMobileNet Predictions:")
for label, prob in predict(mobilenet, image):
    print(f"{label}: {prob:.4f}")
# Out:
# AlexNet Predictions:
# daisy: 0.9724
# bee: 0.0241
# vase: 0.0008
# ant: 0.0008
# fly: 0.0004
#
# ResNet101 Predictions:
# daisy: 0.9943
# bee: 0.0010
# earthstar: 0.0007
# vase: 0.0005
# sulphur_butterfly: 0.0004
#
# MobileNet Predictions:
# daisy: 0.9327
# vase: 0.0165
# bee: 0.0110
# ant: 0.0068
# earthstar: 0.0051

# %%
from torchvision import datasets
from torch.utils.data import DataLoader

# Data transforms
train_transform = transforms.Compose([
    transforms.Resize((224,224)),
    transforms.ToTensor(),
])

train_data = datasets.ImageFolder("images.jpg", transform=train_transform)
train_loader = DataLoader(train_data, batch_size=32, shuffle=True)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_2418/3817536322.py in <cell line: 0>()
#       8 ])
#       9
# ---> 10 train_data = datasets.ImageFolder("images.jpg", transform=train_transform)
#      11 train_loader = DataLoader(train_data, batch_size=32, shuffle=True)
#
# /usr/local/lib/python3.12/dist-packages/torchvision/datasets/folder.py in __init__(self, root, transform, target_transform, loader, is_valid_file, allow_empty)
#     326         allow_empty: bool = False,
#     327     ):
# --> 328         super().__init__(
#     329             root,
#     330             loader,
#
# /usr/local/lib/python3.12/dist-packages/torchvision/datasets/folder.py in __init__(self, root, loader, extensions, transform, target_transform, is_valid_file, allow_empty)
#     147     ) -> None:
# ...

# %%
import torch.nn as nn
from torchvision import models

# Load a pre-trained ResNet-18 model
model = models.resnet18(pretrained=True)

# Get the number of input features for the last layer
num_ftrs = model.fc.in_features

# Replace the final fully connected layer with a new one
# `train_data.num_classes` will give us the number of unique classes
model.fc = nn.Linear(num_ftrs, len(train_data.classes))

# Move the model to GPU if available
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model = model.to(device)

print(f"Model loaded and modified. Number of classes: {len(train_data.classes)}")
print(model)
# Out:
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 153MB/s]
# Model loaded and modified. Number of classes: 4
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
# ...

# %% [markdown]
# This code sets up a pre-trained ResNet-18 model and customizes its final classification layer to match the number of classes found in your `dataset` directory.

# %%
import os

# Create the main dataset directory
os.makedirs('dataset', exist_ok=True)

# Create class subdirectories
os.makedirs('dataset/class_C1', exist_ok=True)
os.makedirs('dataset/class_C2', exist_ok=True)
os.makedirs('dataset/class_C3', exist_ok=True)
os.makedirs('dataset/other', exist_ok=True)

# %%
import shutil

# Move images to their respective class subdirectories
shutil.move('C1.jpg', 'dataset/class_C1/')
shutil.move('C1 (1).jpg', 'dataset/class_C1/')
shutil.move('C2.jpg', 'dataset/class_C2/')
shutil.move('C2 (1).jpg', 'dataset/class_C2/')
shutil.move('C3.jpg', 'dataset/class_C3/')
shutil.move('C3 (1).jpg', 'dataset/class_C3/')

# Move remaining images to 'other' class
shutil.move('D.jpg', 'dataset/other/')
shutil.move('E.jpg', 'dataset/other/')
shutil.move('L.jpg', 'dataset/other/')
shutil.move('P.jpg', 'dataset/other/')
shutil.move('Z.jpg', 'dataset/other/')
shutil.move('images.jpg', 'dataset/other/')

print("Images have been organized into the 'dataset' directory.")
# Out:
# Images have been organized into the 'dataset' directory.

# %% [markdown]
# Now that the images are organized, we can correctly use `torchvision.datasets.ImageFolder` by pointing it to the `dataset` directory.

# %%
from torchvision import datasets
from torch.utils.data import DataLoader

# Data transforms
train_transform = transforms.Compose([
    transforms.Resize((224,224)),
    transforms.ToTensor(),
])

train_data = datasets.ImageFolder("dataset", transform=train_transform)
train_loader = DataLoader(train_data, batch_size=32, shuffle=True)

# %%
ls -F
# Out:
# 'C1 (1).jpg'  'C3 (1).jpg'   imagenet_class_index.json   sample_data/
#  C1.jpg        C3.jpg        images.jpg                  Z.jpg
# 'C2 (1).jpg'   D.jpg         L.jpg
#  C2.jpg        E.jpg         P.jpg
